# %%
import pandas as pd
import numpy as np
import time
import requests
from bs4 import BeautifulSoup

# %%
def fetch_author_info(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        score_elements = soup.find_all("div", class_="m-scorecard__item")
        percentages = []
        check_nums = []
        for element in score_elements:
            percentage = element.find('span', class_='m-scorecard__value').find('noscript').text
            check_num = int(element.find('p', class_='m-scorecard__checks').find('a').text.split(' ')[0])
            percentages.append(percentage)
            check_nums.append(check_num)
        return percentages, check_nums
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %%
def fetch_content_info(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        try:
            lists = soup.find("div", class_="short-on-time").find_all('li')
            summaries = []
            for bullet_point in lists:
                summary = bullet_point.text.strip('\n')
                summaries.append(summary)
        except:
            summaries = []
        
        
        article = soup.find('article', class_='m-textblock').text.replace('\n', '').replace('\t', '')
        return summaries, article
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %%
def custom_filter(tag):
    return tag.name == "a" and tag.get('href', '').startswith('/factchecks/')

# %%
# The current number of pages
pages = 793
info_list = []
url_org = 'https://www.politifact.com'

for page_id in range(662, 773):
    time.sleep(3)
    url = f"https://www.politifact.com/factchecks/list/?page={page_id + 1}&"
    response = requests.get(url)
    try:
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            article_elements = soup.find_all("li", class_="o-listicle__item")
            for article in article_elements:
                media = article.find("a", class_="m-statement__name").text.strip('\n')
                when_where = article.find("div", class_="m-statement__desc").text.strip('\n')
                content = article.find_all(custom_filter)[0].text.strip('\n')
                credibility = article.find_all("img")[-1].get('alt')
                author = article.find("footer", class_="m-statement__footer").text.strip('\n').split('•')[0].strip('By ')
                documented_time = article.find("footer", class_="m-statement__footer").text.strip('\n').split('•')[1]                
                author_url = url_org + article.find('div', class_='m-statement__meta').find('a').get('href')
                content_url = url_org + article.find('div', class_='m-statement__quote').find('a').get('href')
                percentages, check_nums = fetch_author_info(author_url)
                percentages = np.array(percentages)
                check_nums = np.array(check_nums)
                summaries, article = fetch_content_info(content_url)
                summaries = np.array(summaries)
                info_list.append([media, when_where, content, credibility, author, documented_time, percentages, check_nums, summaries, article])      
            print(f'Page {page_id + 1} is done.')
        else:
            print(f"Failed to retrieve the page. Status code: {response.status_code}")  
    except:
        print(f'Failed at this page')
        poli_df = pd.DataFrame(np.array(info_list), columns = ['media', 'when/where', 'content', 'label', 'speaker', 'documented_time', 'percentages', 'check_nums', 'summaries', 'article'])
        poli_df.to_csv('politifact_data.csv')
        break
poli_df = pd.DataFrame(np.array(info_list), columns = ['media', 'when/where', 'content', 'label', 'speaker', 'documented_time', 'percentages', 'check_nums', 'summaries', 'article'])
poli_df.to_csv('politifact_data.csv')
# Out:
# Page 663 is done.
# Page 664 is done.
# Page 665 is done.
# Page 666 is done.
# Page 667 is done.
# Page 668 is done.
# Page 669 is done.
# Page 670 is done.
# Page 671 is done.
# Page 672 is done.
# Page 673 is done.
# Page 674 is done.
# Page 675 is done.
# Page 676 is done.
# Page 677 is done.
# Page 678 is done.
# Page 679 is done.
# Page 680 is done.
# Page 681 is done.
# Page 682 is done.
# Page 683 is done.
# Page 684 is done.
# Page 685 is done.
# Page 686 is done.
# Page 687 is done.
# Page 688 is done.
# Page 689 is done.
# Page 690 is done.
# Page 691 is done.
# Page 692 is done.
# Page 693 is done.
# Page 694 is done.
# Page 695 is done.
# Page 696 is done.
# Page 697 is done.
# Page 698 is done.
# Page 699 is done.
# Page 700 is done.
# Page 701 is done.
# Page 702 is done.
# Page 703 is done.
# Page 704 is done.
# Page 705 is done.
# Page 706 is done.
# Page 707 is done.
# Page 708 is done.
# Page 709 is done.
# Page 710 is done.
# Page 711 is done.
# Page 712 is done.
# Page 713 is done.
# Page 714 is done.
# Page 715 is done.
# Page 716 is done.
# Page 717 is done.
# Page 718 is done.
# Page 719 is done.
# Page 720 is done.
# Page 721 is done.
# Page 722 is done.
# Page 723 is done.
# Page 724 is done.
# Page 725 is done.
# Page 726 is done.
# Page 727 is done.
# Page 728 is done.
# Page 729 is done.
# Page 730 is done.
# Page 731 is done.
# Page 732 is done.
# Page 733 is done.
# Page 734 is done.
# Page 735 is done.
# Page 736 is done.
# Page 737 is done.
# Page 738 is done.
# Page 739 is done.
# Page 740 is done.
# Page 741 is done.
# Page 742 is done.
# Page 743 is done.
# Page 744 is done.
# Page 745 is done.
# Page 746 is done.
# Page 747 is done.
# Page 748 is done.
# Page 749 is done.
# Page 750 is done.
# Page 751 is done.
# Page 752 is done.
# Page 753 is done.
# Page 754 is done.
# Page 755 is done.
# Page 756 is done.
# Page 757 is done.
# Page 758 is done.
# Page 759 is done.
# Page 760 is done.
# Page 761 is done.
# Page 762 is done.
# Page 763 is done.
# Page 764 is done.
# Page 765 is done.
# Page 766 is done.
# Page 767 is done.
# Page 768 is done.
# Page 769 is done.
# Page 770 is done.
# Page 771 is done.
# Page 772 is done.
# Page 773 is done.
# /tmp/ipykernel_135/3691535606.py:37: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   poli_df = pd.DataFrame(np.array(info_list), columns = ['media', 'when/where', 'content', 'label', 'speaker', 'documented_time', 'percentages', 'check_nums', 'summaries', 'article'])

# %%
scraped_data = pd.read_csv('politifact_data.csv')
scraped_data
# Out:
#                  media                                         when/where  \
# 0      Instagram posts  stated on October 28, 2023 in a screenshot sha...
# 1         Scott Walker               stated on May 30, 2023 in Interview:
# 2      Instagram posts              stated on October 27, 2023 in a post:
# 3          Viral image   stated on October 27, 2023 in an Instagram post:
# 4       Facebook posts   stated on September 25, 2023 in a Facebook post:
# ...                ...                                                ...
# 25610    Mike Huckabee        stated on June 5, 2007 in Manchester, N.H.:
# 25611    Rudy Giuliani  stated on July 30, 2007 in a speech in Laconia...
# 25612  Bill Richardson                stated on May 10, 2007 in a TV Ad.:
# 25613  Hillary Clinton         stated on July 22, 2007 in Washington, DC:
# 25614    Sam Brownback                            stated on June 8, 2007:
#
#                                                  content        label  \
# 0      “Haaretz investigation reveals discrepancies i...        false
# 1      “Wisconsin has historically … and I think larg...  barely-true
# 2      “The airport in Salzburg, Austria, has a count...        false
# 3      Video shows Palestinians pretending to be corp...        false
# 4      The life span of a wind tower generator lasts ...        false
# ...                                                  ...          ...
# 25610  "I'll tell you what I can tell this country: I...        false
# 25611  "Democrats are kind of falling over each other...    half-true
# 25612  "I used tax cuts to help create over 80,000 jo...  mostly-true
# 25613  "Corporate profits are up, CEO pay is up, but ...         true
# 25614  "I'm for a three-state political solution in I...         true
#
#                    speaker    documented_time  \
# 0           Madison Czopek   October 31, 2023
# 1            Laura Schulte   October 31, 2023
# 2           Ciara O'Rourke   October 30, 2023
# 3           Ciara O'Rourke   October 30, 2023
# 4          Loreben Tuquero   October 30, 2023
# ...                    ...                ...
# 25610  Angie Drobnic Holan     August 7, 2007
# 25611          John Martin     August 6, 2007
# 25612            ill Adair     August 1, 2007
# 25613            ill Adair     August 1, 2007
# 25614          Nell Benton      July 10, 2007
#
#                                  percentages                       check_nums  \
# 0          ['0%' '0%' '2%' '7%' '67%' '21%']        [  5   3  16  54 473 152]
# 1       ['12%' '21%' '18%' '19%' '21%' '5%']              [26 45 39 41 44 11]
# 2          ['0%' '0%' '2%' '7%' '67%' '21%']        [  5   3  16  54 473 152]
# 3          ['0%' '1%' '2%' '4%' '62%' '28%']        [  4  13  35  53 745 336]
# 4          ['0%' '1%' '4%' '9%' '59%' '23%']  [  24   50  108  247 1519  594]
# ...                                      ...                              ...
# 25610    ['19%' '7%' '21%' '28%' '14%' '9%']              [ 8  3  9 12  6  4]
# 25611  ['15%' '13%' '18%' '16%' '22%' '13%']              [ 8  7 10  9 12  7]
# 25612    ['11%' '47%' '17%' '5%' '11%' '5%']                    [2 8 3 1 2 1]
# 25613   ['23%' '25%' '23%' '14%' '10%' '2%']              [72 76 70 43 31  9]
# 25614     ['50%' '0%' '0%' '25%' '25%' '0%']                    [2 0 0 1 1 0]
#
#                                                summaries  \
# 0      ['Haaretz, an Israeli newspaper, said on X tha...
# 1      ['Although Wisconsin has voted for more Democr...
# 2                                                     []
# 3      ['This video is 10 years old and shows student...
# 4      ['A study by energy industry experts showed th...
# ...                                                  ...
# 25610                                                 []
# 25611                                                 []
# 25612                                                 []
# 25613                                                 []
# 25614                                                 []
#
#                                                  article
# 0      A viral Oct. 28 social media post claimed that...
# 1      In 2016, Wisconsin helped to swing the preside...
# 2      A social media post poised to encourage people...
# 3      The Gaza Health Ministry has said the Palestin...
# 4      Let’s clear the air. Do wind turbine component...
# ...                                                  ...
# 25610  Huckabee says there are "probably plenty" of p...
# 25611  It's not entirely clear from the context wheth...
# 25612  Statistics from the Bureau of Labor Statistics...
# 25613  Corporate profits have been rising. The Commer...
# 25614  Indeed, Brownback teamed up with Sen. Joe Bide...
#
# [25615 rows x 10 columns]

# %%
import zipfile

file_to_zip = 'politifact_data.csv'
zip_file_name = 'politifact_data.zip'

with zipfile.ZipFile(zip_file_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(file_to_zip)

print(f'{file_to_zip} has been zipped to {zip_file_name}')
# Out:
# politifact_data.csv has been zipped to politifact_data.zip
