# %%
import instaloader
import time
from duckduckgo_search import DDGS
from IPython.display import clear_output
import httpx
import pandas as pd
import numpy as np

# %%
# Get the username by scraping using Duckduck Go search api

# %%
social_media = pd.read_csv('credibility.csv', index_col=None).drop(columns = 'Unnamed: 0')
social_media
# Out:
#                            source  credibility_score  \
# 0                 Instagram posts               1.74
# 1                    Scott Walker               5.14
# 2                     Viral image               1.60
# 3                  Facebook posts               1.86
# 4         New York Citizens Audit               2.00
# ...                           ...                ...
# 4695    Freedom Defense Advocates               0.00
# 4696  Spike the Romney Attack Dog               8.00
# 4697        Log Cabin Republicans               8.00
# 4698                Sam Brownback               6.50
# 4699                   Obama Girl              10.00
#
#                                          source_history
# 0     Instagram List of most-followed Instagram acco...
# 1     Scott Walker Scott Walker (politician) Scott W...
# 2     Viral phenomenon Imgur The dress Midjourney Da...
# 3     Facebook Facebook 3D Posts Meta Platforms Hist...
# 4     Sovereign citizen movement KPMG BNY Mellon Arc...
# ...                                                 ...
# 4695  United States Army Judge Advocate General's Co...
# 4696  Mitt Romney List of individual dogs January 6 ...
# 4697  Log Cabin Republicans Don Korotsky Norte Log C...
# 4698  Sam Brownback Kansas experiment Sam Brownback ...
# 4699  Amber Lee Ettinger Family of Barack Obama Mich...
#
# [4700 rows x 3 columns]

# %%
source_lst = np.array((social_media['source'].str.replace(' posts', '')))
source_lst[source_lst == 'X'] = 'Twitter'

# %%
# Old Scrape algorithm
# instagram_urls = []
# i = 0
# for name in source_lst:
#     try:
#         with DDGS() as ddgs:
#             results = [r for r in ddgs.text(name +" official instagram", max_results=1)][0]['href']
#             instagram_urls.append(results)
#         if i % 100 == 0:
#             print(f"Iteration", i, "is done")
#             clear_output(wait=True)
#     except httpx.HTTPError as e:
#         instagram_urls.append(None)
#         print(f"Fail to retrieve at ",i, 'with name', name)
#     i += 1
# social_media['instagram_uri'] = np.array(instagram_urls)
# social_media.to_csv('credibility_with_insta_1.csv')
# Out:
# Fail to retrieve at  4692 with name Citizens United Political Victory Fund
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_276/2446522019.py in <module>
#      13         print(f"Fail to retrieve at ",i, 'with name', name)
#      14     i += 1
# ---> 15 social_media['instagram_uri'] = np.array(instagram_urls)
#      16 social_media.to_cse('credibility_with_insta.csv')
#
# NameError: name 'np' is not defined

# %%
# Improved Scrape Algorithm
instagram_urls = []
i = 0
failed_index = []
for name in source_lst:
    try:
        with DDGS() as ddgs:
            results = [r for r in ddgs.text(name + " instagram account", max_results=10)]    
            instagram_account = None
            for item in results:
                if 'instagram.com' in item['href'] and '@' in item['title']:
                    instagram_account = item['href']
                    break
            instagram_urls.append(instagram_account)
            if instagram_account == None:
                failed_index.append(i)
    except httpx.HTTPError as e:
        print(f"Fail to retrieve at ",i, 'with name', name)
        instagram_urls.append(None)
        failed_index.append(i)
    if i % 100 == 0:
            print(f"Iteration", i, "is done")
            clear_output(wait=True)
    i+=1
social_media['instagram_uri'] = np.array(instagram_urls)
# social_media.to_csv('credibility_with_insta_2.csv')
# Out:
# Fail to retrieve at  4613 with name America's Health Insurance Plans
# Fail to retrieve at  4638 with name America's Natural Gas Alliance
# Fail to retrieve at  4673 with name Conservatives for Patients' Rights

# %%
social_media = pd.read_csv('credibility_with_insta_2.csv').drop(columns = 'Unnamed: 0')
cleaned_social_media = social_media[social_media['instagram_uri'].str.contains('instagram', na=False)].reset_index().drop(columns = 'index')

# %%
from urllib.parse import urlparse
def get_username(instagram_url):
    parsed_url = urlparse(instagram_url)
    path_segments = parsed_url.path.strip('/').split('/')
    username = path_segments[-1]
    return username

# %%
cleaned_social_media['username'] = cleaned_social_media['instagram_uri'].apply(get_username)

# %%
cleaned_social_media
# Out:
#                            source  credibility_score  \
# 0                 Instagram posts               1.74
# 1                    Scott Walker               5.14
# 2         New York Citizens Audit               2.00
# 3                    Steve Kirsch               0.80
# 4                   Shannon Watts               6.00
# ...                           ...                ...
# 4005    Freedom Defense Advocates               0.00
# 4006  Spike the Romney Attack Dog               8.00
# 4007        Log Cabin Republicans               8.00
# 4008                Sam Brownback               6.50
# 4009                   Obama Girl              10.00
#
#                                          source_history  \
# 0     Instagram List of most-followed Instagram acco...
# 1     Scott Walker Scott Walker (politician) Scott W...
# 2     Sovereign citizen movement KPMG BNY Mellon Arc...
# 3     Steve Kirsch Stan Kirsch Against All Odds (198...
# 4     Shannon Watts Watts family murders Shannon Wat...
# ...                                                 ...
# 4005  United States Army Judge Advocate General's Co...
# 4006  Mitt Romney List of individual dogs January 6 ...
# 4007  Log Cabin Republicans Don Korotsky Norte Log C...
# 4008  Sam Brownback Kansas experiment Sam Brownback ...
# 4009  Amber Lee Ettinger Family of Barack Obama Mich...
#
#                                           instagram_uri  \
# 0                  https://www.instagram.com/instagram/
# 1                https://www.instagram.com/scottwalker/
# 2     https://www.instagram.com/newyorkcitizensaudit...
# 3              https://www.instagram.com/steventkirsch/
# 4              https://www.instagram.com/shannonrwatts/
# ...                                                 ...
# 4005           https://www.instagram.com/freedomguards/
# 4006  https://www.instagram.com/spikeakanickilrettil...
# 4007        https://www.instagram.com/logcabincolorado/
# 4008            https://www.instagram.com/govbrownback/
# 4009           https://www.instagram.com/michelleobama/
#
#                       username
# 0                    instagram
# 1                  scottwalker
# 2     newyorkcitizensauditnews
# 3                steventkirsch
# 4                shannonrwatts
# ...                        ...
# 4005             freedomguards
# 4006  spikeakanickilrettiliano
# 4007          logcabincolorado
# 4008              govbrownback
# 4009             michelleobama
#
# [4010 rows x 5 columns]

# %%
def scrape_account(username, bot):
    try:
        caption_lst = []
        profile = instaloader.Profile.from_username(bot.context, username)
        print(f"Profile '{username}' exists.")
        time.sleep(5)
        return profile.username, profile.biography, profile.userid, profile.mediacount, profile.followers, profile.followees, profile.is_verified#, caption_lst
    
    except instaloader.ProfileNotExistsException:
        print(f"Profile '{username}' does not exist.")
        return None
bot = instaloader.Instaloader()
instaloader.Instaloader.login(bot, user = 'seanjiang10', passwd = '1037635008')

# %%
usernames = np.array(cleaned_social_media['instagram_username'])
i = 0
account_info_lst = []
for name in usernames:
    result = scrape_account(name, bot)
    print(f"Iteration", i, "is done")
    account_info_lst.append(result)
    if i % 10 == 0:
        clear_output(wait=True)
    i += 1
# reliability_df = pd.DataFrame(account_info_lst, columns = ['username', 'biography','userid','mediacount','followers','followees','is_verified'])
# reliability_df.to_csv('reliability.csv')
# Out:
# Profile 'libertyguardofficial' exists.
# Iteration 4001 is done
# Profile 'focusonthefamily' exists.
# Iteration 4002 is done
# Profile 'mike.gravel' exists.
# Iteration 4003 is done
# Profile 'psychicmediumje' exists.
# Iteration 4004 is done
# Profile 'freedomguards' exists.
# Iteration 4005 is done
# Profile 'spikeakanickilrettiliano' exists.
# Iteration 4006 is done
# Profile 'logcabincolorado' exists.
# Iteration 4007 is done
# Profile 'govbrownback' exists.
# Iteration 4008 is done
# Profile 'michelleobama' exists.
# Iteration 4009 is done

# %%
insta_df = pd.read_csv('reliability.csv').drop(columns = 'Unnamed: 0')
insta_df = insta_df.drop_duplicates(subset='username', keep='last')
insta_df
# Out:
#                       username  \
# 0                  scottwalker
# 1     newyorkcitizensauditnews
# 2                steventkirsch
# 3                shannonrwatts
# 4                 chris_larson
# ...                        ...
# 3669             freedomguards
# 3670  spikeakanickilrettiliano
# 3671          logcabincolorado
# 3672              govbrownback
# 3673             michelleobama
#
#                                               biography       userid  \
# 0     Christian American Husband Father 45th Governo...    586553277
# 1     NY Citizens Audit is a Volunteer based group. ...  50346417000
# 2     Retired serial entrepreneur. Follow me on stev...    184544694
# 3     🎤 Speaker, author, organizer\n🙋‍♀️ “Summoner o...     24779854
# 4                                                   NaN      5941863
# ...                                                 ...          ...
# 3669  # 1 In Exposing Voices of the Unheard Patriots...  33533983021
# 3670  #punge feat @krin183dsacommando  prod @sundayd...   1806764556
# 3671  Official Instagram account of the Log Cabin Re...  45809376743
# 3672  Official campaign account for Kansas Governor ...   1467894876
# 3673  Girl from the South Side and former First Lady...   4302013048
#
#       mediacount  followers  followees  is_verified
# 0           8683      47989        175         True
# 1           1202        891        460        False
# 2             10       4469         20        False
# 3            431     129536       2369         True
# 4           1138       1743        349        False
# ...          ...        ...        ...          ...
# 3669         388      69452        335        False
# 3670         275       2290       1177        False
# 3671         868       1026        696        False
# 3672          63        515         76        False
# 3673         849   57163804         13         True
#
# [3674 rows x 7 columns]

# %%
unique_df = pd.DataFrame({"username" : np.unique(cleaned_social_media[['username']])})
merged_df = pd.merge(insta_df, unique_df, on='username', how='inner').reset_index().drop(columns = 'index')
# merged_df['ratio'] = np.log(merged_df['followers']/(merged_df['followees'].replace(0, 1))
merged_df
# Out:
#                       username  \
# 0                  scottwalker
# 1     newyorkcitizensauditnews
# 2                steventkirsch
# 3                shannonrwatts
# 4                 chris_larson
# ...                        ...
# 3669             freedomguards
# 3670  spikeakanickilrettiliano
# 3671          logcabincolorado
# 3672              govbrownback
# 3673             michelleobama
#
#                                               biography       userid  \
# 0     Christian American Husband Father 45th Governo...    586553277
# 1     NY Citizens Audit is a Volunteer based group. ...  50346417000
# 2     Retired serial entrepreneur. Follow me on stev...    184544694
# 3     🎤 Speaker, author, organizer\n🙋‍♀️ “Summoner o...     24779854
# 4                                                   NaN      5941863
# ...                                                 ...          ...
# 3669  # 1 In Exposing Voices of the Unheard Patriots...  33533983021
# 3670  #punge feat @krin183dsacommando  prod @sundayd...   1806764556
# 3671  Official Instagram account of the Log Cabin Re...  45809376743
# 3672  Official campaign account for Kansas Governor ...   1467894876
# 3673  Girl from the South Side and former First Lady...   4302013048
#
#       mediacount  followers  followees  is_verified
# 0           8683      47989        175         True
# 1           1202        891        460        False
# 2             10       4469         20        False
# 3            431     129536       2369         True
# 4           1138       1743        349        False
# ...          ...        ...        ...          ...
# 3669         388      69452        335        False
# 3670         275       2290       1177        False
# 3671         868       1026        696        False
# 3672          63        515         76        False
# 3673         849   57163804         13         True
#
# [3674 rows x 7 columns]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import MinMaxScaler

features = merged_df[['mediacount', 'followers', 'followees', 'is_verified']]
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
agglomerative = AgglomerativeClustering(n_clusters=None, distance_threshold=10, linkage='ward')
merged_df['reliability_score'] = agglomerative.fit_predict(scaled_features)
min_max_scaler = MinMaxScaler(feature_range=(1, 5))
merged_df['reliability_score'] = min_max_scaler.fit_transform(merged_df['reliability_score'].values.reshape(-1, 1))
merged_df[['username', 'reliability_score']]
# Out:
#                       username  reliability_score
# 0                  scottwalker           1.000000
# 1     newyorkcitizensauditnews           2.333333
# 2                steventkirsch           2.333333
# 3                shannonrwatts           3.444444
# 4                 chris_larson           2.333333
# ...                        ...                ...
# 3669             freedomguards           2.333333
# 3670  spikeakanickilrettiliano           3.888889
# 3671          logcabincolorado           2.333333
# 3672              govbrownback           2.333333
# 3673             michelleobama           4.111111
#
# [3674 rows x 2 columns]

# %%
# # Improved Scrape Algorithm
# instagram_urls = []
# i = 0
# failed_index = []
# for name in source_lst:
#     try:
#         with DDGS() as ddgs:
#             results = [r for r in ddgs.text(name + " instagram account", max_results=5)]    
#             instagram_account = None
#             for item in results:
#                 if 'instagram.com' in item['href'] and '@' in item['title']:
#                     instagram_account = item['href']
#                     print(item)
#                     break
#             instagram_urls.append(instagram_account)
#             if instagram_account == None:
#                 failed_index.append(i)
#     except httpx.HTTPError as e:
#         print(f"Fail to retrieve at ",i, 'with name', name)
#         instagram_urls.append(None)
#         failed_index.append(i)
#     break
#     if i % 100 == 0:
#             print(f"Iteration", i, "is done")
#             clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_97/731507249.py in <module>
#       6     try:
#       7         with DDGS() as ddgs:
# ----> 8             results = [r for r in ddgs.text(name + " instagram account", max_results=5)]
#       9             instagram_account = None
#      10             for item in results:
#
# /tmp/ipykernel_97/731507249.py in <listcomp>(.0)
#       6     try:
#       7         with DDGS() as ddgs:
# ----> 8             results = [r for r in ddgs.text(name + " instagram account", max_results=5)]
#       9             instagram_account = None
#      10             for item in results:
#
# ~/.local/lib/python3.9/site-packages/duckduckgo_search/duckduckgo_search.py in text(self, keywords, region, safesearch, timelimit, backend, max_results)
#      94             results = self._text_lite(keywords, region, timelimit, max_results)
#      95
# ---> 96         for i, result in enumerate(results, start=1):
#      97             yield result
#      98             if max_results and i >= max_results:
#
# ~/.local/lib/python3.9/site-packages/duckduckgo_search/duckduckgo_search.py in _text_api(self, keywords, region, safesearch, timelimit, max_results)
#     122         assert keywords, "keywords is mandatory"
#     123
# --> 124         vqd = self._get_vqd(keywords)
#     125         assert vqd, "error in getting vqd"
#     126
#
# ~/.local/lib/python3.9/site-packages/duckduckgo_search/duckduckgo_search.py in _get_vqd(self, keywords)
#      58     def _get_vqd(self, keywords: str) -> Optional[str]:
#      59         """Get vqd value for a search query."""
# ---> 60         resp = self._get_url("POST", "https://duckduckgo.com", data={"q": keywords})
#      61         if resp:
#      62             return _extract_vqd(resp.content)
#
# ~/.local/lib/python3.9/site-packages/duckduckgo_search/duckduckgo_search.py in _get_url(self, method, url, **kwargs)
#      53                 logger.warning(f"_get_url() {url} {type(ex).__name__} {ex}")
#      54                 if i >= 2 or "418" in str(ex):
# ---> 55                     raise ex
#      56             sleep(3)
#      57
#
# ~/.local/lib/python3.9/site-packages/duckduckgo_search/duckduckgo_search.py in _get_url(self, method, url, **kwargs)
#      44         for i in range(3):
#      45             try:
# ---> 46                 resp = self._client.request(method, url, follow_redirects=True, **kwargs)
#      47                 if _is_500_in_url(str(resp.url)) or resp.status_code == 202:
#      48                     raise httpx._exceptions.HTTPError("")
#
# TypeError: request() got an unexpected keyword argument 'follow_redirects'
