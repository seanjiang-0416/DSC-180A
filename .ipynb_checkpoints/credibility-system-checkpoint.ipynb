# %%
import numpy as np
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from string import punctuation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from transformers import BertTokenizer, BertForSequenceClassification
import torch
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import ast

# %%
standard = ['True', 'Mostly True ','Half True ', 'Mostly False', 'False', 'Pants on Fire']
score = np.array([10, 8, 6, 4, 2, 0])

# %%
poli_df = pd.read_csv('politifact_data.csv')

# %%
def transform_percentages(col):
    return sum(np.array(ast.literal_eval(col.replace('%', '').replace('\'', '').replace(' ', ',')))/100 * score)

# %%
# Propose credibility score/Reliable source

# %%
statement_labels = {
    'pants-fire': 0,
    'false': 1,
    'barely-true': 2,
    'half-true': 3,
    'mostly-true': 4,
    'true': 5,
    'half-flip': 6,
    'no-flip': 7,
    'full-flop': 8
}

# %%
poli_df['credibility_score'] = poli_df['percentages'].apply(transform_percentages)
poli_df['label'] = poli_df['label'].map(statement_labels)

# %%
temp_polidf = poli_df[poli_df['summaries'] != '[]']
temp_polidf['summaries'] = temp_polidf['summaries'].apply(lambda x: ast.literal_eval(x))
# Out:
# /tmp/ipykernel_4315/896588058.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_polidf['summaries'] = temp_polidf['summaries'].apply(lambda x: ast.literal_eval(x))

# %%
cleaned_df = temp_polidf[['media', 'content', 'summaries', 'credibility_score', 'label']].reset_index()
cleaned_df
# Out:
#       index            media  \
# 0         0  Instagram posts
# 1         1     Scott Walker
# 2         3      Viral image
# 3         4   Facebook posts
# 4         5  Instagram posts
# ...     ...              ...
# 5912   6903      Nikki Haley
# 5913   6907      Mike Pompeo
# 5914   6929         Bloggers
# 5915   6930         Bloggers
# 5916   7158     Donald Trump
#
#                                                 content  \
# 0     “Haaretz investigation reveals discrepancies i...
# 1     “Wisconsin has historically … and I think larg...
# 2     Video shows Palestinians pretending to be corp...
# 3     The life span of a wind tower generator lasts ...
# 4     Matthew Perry died because of a COVID-19 vaccine.
# ...                                                 ...
# 5912  Says the Democratic leadership and presidentia...
# 5913  "President Trump didn't say he'd go after a cu...
# 5914  "Cory Booker’s son charged with assault after ...
# ...

# %%
X = cleaned_df[['content', 'summaries', 'credibility_score']]
y = cleaned_df['label']

# %%
from sklearn.utils import resample

max_count = cleaned_df['label'].value_counts().max()

# Create an empty DataFrame to store the upsampled data
upsampled_df = pd.DataFrame(columns=cleaned_df.columns)

for label in cleaned_df['label'].unique():
    label_data = cleaned_df[cleaned_df['label'] == label]
    if len(label_data) < max_count:
        upsampled_data = resample(label_data, replace=True, n_samples=max_count, random_state=42)
        upsampled_df = pd.concat([upsampled_df, upsampled_data])
    elif label == 1:
        upsampled_df = pd.concat([upsampled_df, label_data])
# Reset the index
upsampled_df = upsampled_df.reset_index(drop=True)

# %%
X = upsampled_df[['content', 'summaries', 'credibility_score']]
y = upsampled_df['label']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Assuming you have already preprocessed the data
# X should contain your feature columns (summaries and credibility_score)
# y should contain the target column (label)

# Copy the 'summaries' column and preprocess it without modifying the original 'X'
X_preprocessed = X.copy()

# Preprocess the 'summaries' column by joining the list of strings into a single string
X_preprocessed['summaries'] = X_preprocessed['summaries'].apply(lambda x: ' '.join(x))

# Vectorize text data
tfidf_vectorizer = TfidfVectorizer(norm = "l2")
X_summaries = tfidf_vectorizer.fit_transform(X_preprocessed['summaries'])

# Combine text features and 'credibility_score'
X_summaries_reset = pd.DataFrame(X_summaries.toarray()).reset_index(drop=True)
X_preprocessed_reset = X_preprocessed['credibility_score'].reset_index(drop=True)
X_features = pd.concat([X_summaries_reset, X_preprocessed_reset], axis=1)

y = y.astype(int)
# Split the preprocessed data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_features, y, test_size=0.2, random_state=42)

# Initialize and train a model (Random Forest in this example)
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.981751184418319

# %%
# Limitation: Too much repetitive except 1, can apply the same approach but use it on a more realistic dataset
# Need to come up with ways to summarize the article
